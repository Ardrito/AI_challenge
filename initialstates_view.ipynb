# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
init_state = pd.read_csv('00000_to_02284-initial_states.csv')

# %%
print(init_state.to_string())
# Out:
#       File ID            Timestamp  Semi-major Axis (km)  Eccentricity  Inclination (deg)  RAAN (deg)  Argument of Perigee (deg)  True Anomaly (deg)  Latitude (deg)  Longitude (deg)  Altitude (km)
# 0           0  2000-08-02 04:50:33           6826.387247      0.003882          87.275306  144.135111                 257.314389          102.383270    4.363781e+01    -6.254313e+01   4.664489e+02
# 1           1  2000-08-03 19:51:01           6826.327748      0.003879          87.275694  143.529694                 250.438806          109.273118    4.344446e+01     7.013971e+01   4.634351e+02
# 2           2  2000-08-05 05:40:05           6819.634802      0.004114          87.268611  142.972111                 244.549389          115.138737    1.976425e+01     1.045213e+02   4.716255e+02
# 3           3  2000-08-06 05:02:20           6819.606603      0.004134          87.268194  142.608389                 241.172000          118.545161    1.245074e+01     1.122396e+02   4.703859e+02
# ...

# %%
X,Y = pd.to_datetime(init_state['Timestamp']),init_state['RAAN (deg)']

# %%
print(X,Y)
# Out:
# 0   2000-08-02 04:50:33
# 1   2000-08-03 19:51:01
# 2   2000-08-05 05:40:05
# 3   2000-08-06 05:02:20
# 4   2000-08-08 20:54:57
# 5   2000-08-09 20:17:05
# 6   2000-08-11 19:01:16
# 7   2000-09-03 02:50:45
# 8   2000-09-05 15:40:48
# 9   2000-09-06 02:35:56
# Name: Timestamp, dtype: datetime64[ns] 0    0.003882
# 1    0.003879
# 2    0.004114
# 3    0.004134
# 4    0.004178
# 5    0.004200
# 6    0.004243
# 7    0.004379
# 8    0.004435
# 9    0.004413
# Name: Eccentricity, dtype: float64

# %%
plt.scatter(X,Y,s=2)
plt.xticks(rotation=90)
# Out:
# (array([11323., 11688., 12053., 12418., 12784., 13149., 13514., 13879.,
#         14245., 14610., 14975.]),
#  [Text(11323.0, 0, '2001'),
#   Text(11688.0, 0, '2002'),
#   Text(12053.0, 0, '2003'),
#   Text(12418.0, 0, '2004'),
#   Text(12784.0, 0, '2005'),
#   Text(13149.0, 0, '2006'),
#   Text(13514.0, 0, '2007'),
#   Text(13879.0, 0, '2008'),
#   Text(14245.0, 0, '2009'),
#   Text(14610.0, 0, '2010'),
#   Text(14975.0, 0, '2011')])
